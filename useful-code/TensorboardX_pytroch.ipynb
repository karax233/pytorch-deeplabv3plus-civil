# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#运行tensorboard
# %load_ext tensorboard

# %%
from tensorboardX import SummaryWriter
writer1 = SummaryWriter('/content/drive/MyDrive/Lab2020/Liu/Deeplab_pytorch/pytorch-deeplab-xception/run/five_types_damage/five_types_damage_new_01_0624/experiment_3')

# %%
#启动tensorboard
# %tensorboard --logdir=/content/drive/MyDrive/Lab2020/Liu/Deeplab_pytorch/pytorch-deeplab-xception/run/five_types_damage/five_types_damage_0512/experiment_0
